# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoFortezaBenito/deeplearning/blob/main/AA_Practica3_Grupo10_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import tensorflow as tf
import keras
get_ipython().run_line_magic('matplotlib', 'inline')
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# #Introdución al Problema

# %% [markdown]
# En el presente trabajo se propone la creación de un modelo de red neuronal convolucional (CNN) para la clasificación de imágenes en 100 categorías. El conjunto de datos utilizado será el CIFAR-100, que consta de 600 imágenes de 32x32 píxeles por categoría, con un total de 60.000 imágenes de entrenamiento y 10.000 imágenes de prueba.
# El objetivo del trabajo es diseñar un modelo que sea capaz de alcanzar la mayor precisión posible en los datos de prueba. Para ello, se seguirá un enfoque metodológico basado en la construcción de un modelo base y su posterior mejora mediante la incorporación de nuevos componentes o la modificación de los parámetros existentes.
# En la primera parte del trabajo se realizará una descripción del conjunto de datos CIFAR-100, así como una introducción a las CNN. En la segunda parte se presentará la metodología seguida para el diseño y entrenamiento del modelo. En la tercera parte se mostrarán los resultados obtenidos y se realizarán algunas reflexiones sobre las posibles mejoras que podrían aplicarse al modelo.
#
# **DESCRIPCIÓN DEL CONJUNTO DE DATOS**
#
# El conjunto de datos CIFAR-100 (Instituto Canadiense de Investigación Avanzada, 100 clases) es un subconjunto del conjunto de datos Tiny Images y consta de 60000 imágenes en color de 32x32. Las 100 clases del CIFAR-100 se agrupan en 20 superclases. Hay 600 imágenes por clase. Cada imagen viene con una etiqueta "fina" (la clase a la que pertenece) y una etiqueta "gruesa" (la superclase a la que pertenece). Hay 500 imágenes de entrenamiento y 100 imágenes de prueba por clase.

# %% [markdown]
# En primer lugar, se carga la base de datos con los datos mencionados.

# %%
# Descargamos la base de datos
(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.cifar100.load_data()

# Tamaño de los conuntos
print(f"x_train shape: {train_data.shape}")
print(f"y_train shape: {train_labels.shape}")
print(f"x_test shape: {test_data.shape}")
print(f"y_test shape: {test_labels.shape}")

# Número de muestras
print(f"Train: {train_data.shape[0]}")
print(f"Test: {test_data.shape[0]}")

# Data format
print(type(train_data))
print(type(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3)
# y_test shape: (10000, 1)
# Train: 50000
# Test: 10000
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Show randomly 16 images in the CIFAR-100
plt.figure(figsize=(10, 10))
for i in range (16):
  rand_num = np.random.randint(0, 50000)
  cifar_img = plt.subplot(4,4, i+1)
  plt.imshow(train_data[rand_num])

# %% [markdown]
# ##Preprocesamiento de los datos

# %%
from keras.utils import to_categorical
# Normalize images
train_data = train_data.astype('float32')/255
test_data = test_data.astype('float32')/255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
from sklearn.model_selection import train_test_split
# Split: Divide los datos de entrenamiento en entrenamiento y validación con razón de 80/20
train_x, val_x, train_y, val_y = train_test_split(train_data, train_labels,
                                                  test_size = 0.2,
                                                  random_state = 123) # para que la partición siempre sea de la misma manera

# %%
# Se definen variables que van a contener los resultados de los entrenamientos
HISTORY = []
TEST_LOSS = []
TEST_ACC = []

# %%
#Se definen las funciones a utilizar durante el desarrollo de la practica
import matplotlib.pyplot as plt

#Gráfica la pérdida y precisión del modelo seleccionado
def training_plot(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(1, len(acc) + 1)
  plt.plot(epochs, acc, 'bo', label='Training acc')
  plt.plot(epochs, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()
  plt.figure()
  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()
  plt.show()

# Curvas de aprendizaje
"""
Notas: Los elementos de HISTORY son diccionarios que contienen los nombres de las métricas como claves
y sus valores (.values()) son listas con los valores de las métricas durante el entrenamiento model.fit
"""
def curvas_aprendizaje(HISTORY, nfilas, ncol, size = (18,10), title = []):
    # Función para imprimir las curvas de aprendizaje en una rejilla de nfilas x ncol
    # Argumentos: HISTORY = Lista con variables history de keras (obtenidas de model.fit)
    #        nfilas, ncol = Nº de filas y columnas de la rejilla
    #                size = Tamaño total de la rejilla (por defecto es (18,10))
    # !Importante: El nº total de filas x col debe ser superiror al de los elementos pasados como argumento en HISTORY
    if len(HISTORY) > nfilas*ncol:
        print("Error. Dimensiones incompatibles")
        return 0
    else:
        fig = plt.figure(figsize=size) # Especifica tamaño de la figura

        for i, registro in enumerate(HISTORY):

            plt.subplot(nfilas, ncol, i+1) # Añade subplot (gráfica para un modelo)
            if title:
              plt.title(title[i])
            else:
              plt.title("Modelo " + str(i+1)) # Formato de cada gráfica
            plt.xlabel('Épocas')
            plt.ylim((0,2))

            acc = registro.history['accuracy']
            loss = registro.history['loss']

            x = list(range(1, len(acc) + 1))

            plt.plot(x, loss, 'o-') # Imprime
            plt.plot(x, acc, 'o-')

            plt.xticks(x)
            plt.legend(list(registro.history.keys()))
            plt.text(len(x), loss[len(loss)-1], str(round(loss[len(loss)-1],3))) # Valor punto final  loss
            plt.text(len(x), acc[len(acc)-1], str(round(acc[len(acc)-1],3))) # Valor punto final  loss

    fig.tight_layout()
    plt.show()

# Gráfico de barras horizontales
def testerror_testacc(ERROR, ACC, titles, size = (12,12)):
    fig = plt.figure(figsize=size) # Especifica tamaño de la figura

    # Ordena pérdida en orden ascendente y precisión en orden descendente
    sorted_err = dict(zip(titles, ERROR))
    sorted_err = dict(sorted(sorted_err.items(), key = lambda x: x[1], reverse=True))

    sorted_acc = dict(zip(titles, ACC))
    sorted_acc = dict(sorted(sorted_acc.items(), key = lambda x: x[1]))

    # Gráfica
    plt.subplot(1, 2, 1)
    plt.barh(list(sorted_err.keys()), list(sorted_err.values()))
    plt.title('Test error')

    plt.subplot(1,2,2)
    plt.barh(list(sorted_acc.keys()), list(sorted_acc.values()), color='orange')
    plt.title('Test accuracy')

    fig.tight_layout()
    plt.show()

# %% [markdown]
# Medida del Éxito

# %% [markdown]
# Con la intención de evaluar el resultado de los diferentes modelos se definen los siguientes indicadores de servicio, que se aplicarán a todos los modelos utilizados en igualdad de condiciones. Los indicadores de servicio se denominan también "Key Performance Indicator"(KPI) y su cálculo permite una valoración objetiva de cada modelo utilizado.
#
# El primer indicador de servicio propuesto es la precisión obtenida con los datos de test. Esta medida nos otorgará la eficiencia en la identificación de las subclases con imágenes nunca antes vistas. Su fórmula viene dada por:
#
#
#
# ```
# Accuracy = True Positive / (True Positive + False Positive)
# ```
#
#
#
# El segundo indicador a considerar es el tiempo de ejecución en igualdad de condiciones de uds. de procesamiento (4 GPUs). El tiempo de ejecución sobre las mismas capacidades de procesamiento es proporcional a la complejidad de los modelos.

# %% [markdown]
# #Modelos

# %% [markdown]
# Para comparar la mejora del rendimiento en función de los cambios aplicados a un modelo que llamaremos modelo base o de referencia se obtendrán los KPIs definidos anteriormente.
#
# La evolución de los modelos pretende ser progresiva desde el modelo base que es el más simple. A continuación se evaluará el modelo base introduciendo la técnica de *"Data Augmentation"*  con el objetivo de incrementar el volumen de datos de aprendizaje con los datos de entrenamiento. Por último, se aplicará un modelo optimizado utilizando de nuevo *"Data Agumentation"*

# %% [markdown]
# ##Modelo Base

# %% [markdown]
# El modelo base consta de 13.870.484 párametros entrenables y está formado por 3 pilas de capas convolucionales con función de activación Relu seguidas cada una de ellas por una capa de pooling, 2 capas densas con función de activación Relu y una última capa densa con función de activación softmax. Esta última se corresponde con la capa de salida.
#
# A continuación se muestra un esquema de la red:
#
# *   Capa de entrada
# *   [CONV -> RELU] x 2
# *   MAX POOL
# *   [CONV -> RELU] x 2
# *   MAX POOL
# *   [CONV -> RELU] x 2
# *   MAX POOL
# *   FLATTEN
# *   [DENSE -> RELU] x 2
# *   [DENSE -> SOFTMAX] -> Capa de salida

# %% [markdown]
# Las especificaciones de los parámetros utilizados en la construcción del modelo se muestran a continuación:
#
# 1.   En cada capa convolucional se utiliza `padding = "same"`, es decir, se añadan tantas filas y columnas de ceros para que la salida tenga la misma dimensión que la entrada para preservar el tamaño espacial.
# 2.   Se utiliza ReLU en las capas convolucionales debido a su eficiencia en rendimiento en términos de precisión por encima de otras funciones de activación probadas (sigmoid y tang).
# 3.   Se ha utilizado un kernel size de 3x3 para todas las capas convolucionales ya que se quería extraer la mayoría de los detalles de las imágenes.
# 4.   Max pool de tamaño 2x2 ha ofrecido mejores rendimientos que otras opciones como average pool o global pool. Además utilizar un stride de tamaño 2 nos ha permitido obtener un balance entre rendimiento y precisión.
# 5.   El número de filtros utilizados en la primera pila de
# capas convolucionales es 128, 256 y 512 para la tercera. La obtención de estos parámetros empezó desde 32, 64 y 128 y fue incrementandose gradualmente hasta los resultados obtenidos.
# 6.   Tres capas completamente conectadas con 1000 unidades en las dos primeras capas y 100 unidades (unidades iguales a la número de clases) en la última capa (de salida) han sido utilizadas para hacer que la red sea densa y aprenda las características obtenidas del proceso convolucional. Esta combinación de unidades y capas ayudó a que la red clasificara imágenes con más precisión (5% más) que la red con sólo dos capas completamente conectadas.

# %%
#Modelo base
model_ba= Sequential()

#Capa 1
#convolucion
model_ba.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu", input_shape=(32,32,3)))
model_ba.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"))
#pooling
model_ba.add(MaxPool2D(pool_size=2, strides=2))

#Capa 2
#convolucion
model_ba.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
model_ba.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
#pooling
model_ba.add(MaxPool2D(pool_size=2, strides=2))

#Capa 3
#convolution
model_ba.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
model_ba.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
#pooling
model_ba.add(MaxPool2D(pool_size=2, strides=2))

#flattening
model_ba.add(Flatten())

#1º capa densa
model_ba.add(Dense(units=1000, activation="relu"))
#2º capa densa
model_ba.add(Dense(units=1000, activation="relu"))

#capa de salida
model_ba.add(Dense(units=100, activation="softmax"))

# %%
model_ba.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1000)              8193000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 100)               100100
#
# =================================================================
# Total params: 13870484 (52.91 MB)
# Trainable params: 13870484 (52.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Debido a la restricción del entorno de ejecución Google Colab en memoria se ha entrenado el modelo durante 100 épocas manteniendo un `batch_size = 64`. Remarcar que un batch_size de 32 ofrecía una pequeña mejora en el rendimiento en cuanto a precisión pero un incremento de tiempo de ejecución más elvado.
#
# Para la elcción del **optimizador** se han comparado los optimizadores RMSProp, Adam y Nadam con distintas tasas de aprendizaje (0.01, 0,001, 0.0001 y 0.00001) y atendiendo a la precisión obtenida por el modelo base con cada uno de los casos se elige la opción Nadam con `learning rate' = 0.0001`.

# %%
epochs = 100
batch_size = 64
optimizer_ba = keras.optimizers.Nadam(learning_rate=0.0001)

#model compiling
model_ba.compile(optimizer=optimizer_ba, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# El uso de los callbacks `EarlyStopping()` y `ModelCheckpoint()` permiten guardar el modelo óptimo sin desperdiciar recursos de memoria. Para ello se establece como valor de rendimiento la pérdida con los datos de validación con la intención de evitar el sobreentrenamiento y se le da una paciencia de 20.
# La paciencia establece los grados de libertad que deciden cuando detener el entrenamiento, en este caso, si la pérdida con los datos de validación empeora durante 20 épocas seguidas.

# %%
#early stopping
early_stop_ba = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

#model checkpoint para guardar el mejor modelo
model_checkpoint_ba = ModelCheckpoint('Checkpoint_BaseModel.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# %%
# Entrenamiento del modelo
import time
training_start = time.time()
history_ba = model_ba.fit(train_x, train_y,
                      batch_size= batch_size,
                      epochs=epochs,
                      validation_data = (val_x, val_y),
                      callbacks=[early_stop_ba, model_checkpoint_ba],
                      verbose = 1)
training_stop = time.time()
training_time = training_stop - training_start
print(f"Training time: {training_time}")
# Out:
# Epoch 1/100
# 625/625 [==============================] - ETA: 0s - loss: 3.9503 - accuracy: 0.0955
# Epoch 1: val_loss improved from inf to 3.44752, saving model to Checkpoint_BaseModel.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 625/625 [==============================] - 42s 40ms/step - loss: 3.9503 - accuracy: 0.0955 - val_loss: 3.4475 - val_accuracy: 0.1807
# Epoch 2/100
# 625/625 [==============================] - ETA: 0s - loss: 3.1467 - accuracy: 0.2331
# Epoch 2: val_loss improved from 3.44752 to 2.93820, saving model to Checkpoint_BaseModel.h5
# 625/625 [==============================] - 24s 38ms/step - loss: 3.1467 - accuracy: 0.2331 - val_loss: 2.9382 - val_accuracy: 0.2749
# Epoch 3/100
# 625/625 [==============================] - ETA: 0s - loss: 2.6673 - accuracy: 0.3307
# Epoch 3: val_loss improved from 2.93820 to 2.72769, saving model to Checkpoint_BaseModel.h5
# 625/625 [==============================] - 25s 40ms/step - loss: 2.6673 - accuracy: 0.3307 - val_loss: 2.7277 - val_accuracy: 0.3241
# Epoch 4/100
# 625/625 [==============================] - ETA: 0s - loss: 2.2671 - accuracy: 0.4139
# Epoch 4: val_loss improved from 2.72769 to 2.56414, saving model to Checkpoint_BaseModel.h5
# 625/625 [==============================] - 25s 40ms/step - loss: 2.2671 - accuracy: 0.4139 - val_loss: 2.5641 - val_accuracy: 0.3598
# Epoch 5/100
# 625/625 [==============================] - ETA: 0s - loss: 1.8636 - accuracy: 0.5042
# Epoch 5: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 40ms/step - loss: 1.8636 - accuracy: 0.5042 - val_loss: 2.6373 - val_accuracy: 0.3636
# Epoch 6/100
# 625/625 [==============================] - ETA: 0s - loss: 1.4064 - accuracy: 0.6127
# Epoch 6: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 40ms/step - loss: 1.4064 - accuracy: 0.6127 - val_loss: 2.6802 - val_accuracy: 0.3741
# Epoch 7/100
# 625/625 [==============================] - ETA: 0s - loss: 0.8957 - accuracy: 0.7441
# Epoch 7: val_loss did not improve from 2.56414
# 625/625 [==============================] - 24s 39ms/step - loss: 0.8957 - accuracy: 0.7441 - val_loss: 3.0784 - val_accuracy: 0.3880
# Epoch 8/100
# 625/625 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8612
# Epoch 8: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.4670 - accuracy: 0.8612 - val_loss: 3.5894 - val_accuracy: 0.3705
# Epoch 9/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9230
# Epoch 9: val_loss did not improve from 2.56414
# 625/625 [==============================] - 24s 39ms/step - loss: 0.2492 - accuracy: 0.9230 - val_loss: 4.3285 - val_accuracy: 0.3634
# Epoch 10/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9467
# Epoch 10: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 41ms/step - loss: 0.1752 - accuracy: 0.9467 - val_loss: 4.8699 - val_accuracy: 0.3639
# Epoch 11/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9572
# Epoch 11: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 39ms/step - loss: 0.1415 - accuracy: 0.9572 - val_loss: 4.7973 - val_accuracy: 0.3698
# Epoch 12/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9598
# Epoch 12: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 41ms/step - loss: 0.1303 - accuracy: 0.9598 - val_loss: 5.1961 - val_accuracy: 0.3673
# Epoch 13/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9677
# Epoch 13: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 41ms/step - loss: 0.1083 - accuracy: 0.9677 - val_loss: 5.2243 - val_accuracy: 0.3646
# Epoch 14/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9665
# Epoch 14: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.1105 - accuracy: 0.9665 - val_loss: 5.2032 - val_accuracy: 0.3727
# Epoch 15/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9720
# Epoch 15: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 39ms/step - loss: 0.0930 - accuracy: 0.9720 - val_loss: 5.3508 - val_accuracy: 0.3698
# Epoch 16/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9719
# Epoch 16: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 40ms/step - loss: 0.0924 - accuracy: 0.9719 - val_loss: 5.8488 - val_accuracy: 0.3712
# Epoch 17/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9761
# Epoch 17: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 39ms/step - loss: 0.0787 - accuracy: 0.9761 - val_loss: 5.8843 - val_accuracy: 0.3584
# Epoch 18/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9748
# Epoch 18: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 40ms/step - loss: 0.0839 - accuracy: 0.9748 - val_loss: 5.3021 - val_accuracy: 0.3630
# Epoch 19/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0791 - accuracy: 0.9755
# Epoch 19: val_loss did not improve from 2.56414
# 625/625 [==============================] - 25s 39ms/step - loss: 0.0791 - accuracy: 0.9755 - val_loss: 5.6733 - val_accuracy: 0.3547
# Epoch 20/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9774
# Epoch 20: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.0756 - accuracy: 0.9774 - val_loss: 5.7062 - val_accuracy: 0.3701
# Epoch 21/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9808
# Epoch 21: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.0635 - accuracy: 0.9808 - val_loss: 5.5661 - val_accuracy: 0.3541
# Epoch 22/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9797
# Epoch 22: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.0674 - accuracy: 0.9797 - val_loss: 5.7844 - val_accuracy: 0.3676
# Epoch 23/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9826
# Epoch 23: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.0615 - accuracy: 0.9826 - val_loss: 5.6008 - val_accuracy: 0.3646
# Epoch 24/100
# 625/625 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9835
# Epoch 24: val_loss did not improve from 2.56414
# 625/625 [==============================] - 26s 41ms/step - loss: 0.0575 - accuracy: 0.9835 - val_loss: 5.9552 - val_accuracy: 0.3701
# Epoch 24: early stopping
# Training time: 622.5056023597717

# %%
HISTORY.append(history_ba)

# %%
# Visualize training process
training_plot(history_ba)

# %% [markdown]
# Tras entrenar el modelo se observa que antes de la epoch 20 el modelo ha obtenido con los datos de entrenamiento una precisión próxima a la máxima. Además a partir de la gráfica de pérdida se observa que el modelo empieza a sobreentrenar demasiado rápido.
#
# Todo esto significa que el modelo se está acoplando demasiado rápido a los datos de entrenamiento y no esta permitiendo converjer con los datos de validación.

# %% [markdown]
# ####Rendimiento

# %%
scores_ba = model_ba.evaluate(test_data, test_labels)
TEST_LOSS.append(scores_ba[0])
TEST_ACC.append(scores_ba[1])
print(f'accuracy on test set: {model_ba.metrics_names[1]} of {scores_ba[1]*100}')
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 5.7945 - accuracy: 0.3710
# accuracy on test set: accuracy of 37.09999918937683

# %% [markdown]
# Con los datos anteriormente descritos se obtienen los siguientes valores:
# *   Tiempo de ejecución: ~644 s en 25 epochs.
# *   Precisión con los datos de test: ~37%

# %% [markdown]
# ##Modelo Base con Data Augmentation

# %% [markdown]
# ###Data Augmentation

# %% [markdown]
# Uno de los principales problemas para la convergencia de cualquier modelo con esta base de datos es la escasez de imágenes por clase en la base de datos (50.000 imágenes repartidas en 100 clases da lugar a 500 imágenes por clase). Para paliar este problema se podría aumentar el número de imágenes por clase añadiendo más pero esto supondría un problema debido a la limitación de memoria establecida por Google Colab. Con estos antecedentes se presenta la técnica DataAugmentation mediante Keras ImageDataGenerator.
#
#  Keras ImageDataGenerator es una técnica que permite aumentar tu número de imágenes en tiempo real mientras tu modelo aún se está entrenando sin suponer un coste de memoria adicional. Consiste en la aplicación de transformaciones sobre las imágenes tales como: rotaciones y traslaciones, aumento y disminución de brillo y zoom entre otras. De esta manera se consiguen datos sintéticos para mejorar el entrenamiento del modelo.

# %% [markdown]
# ![DataAugmentation.PNG](data:image/png;base64,...)

# %% [markdown]
# ###Modelo

# %%
#Modelo base
model_DA= Sequential()

#Capa 1
#convolucion
model_DA.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu", input_shape=(32,32,3)))
model_DA.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"))
#pooling
model_DA.add(MaxPool2D(pool_size=2, strides=2))

#Capa 2
#convolucion
model_DA.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
model_DA.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
#pooling
model_DA.add(MaxPool2D(pool_size=2, strides=2))

#Capa 3
#convolucion
model_DA.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
model_DA.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
#pooling
model_DA.add(MaxPool2D(pool_size=2, strides=2))

#flattening
model_DA.add(Flatten())

#1º capa densa
model_DA.add(Dense(units=1000, activation="relu"))
#2º capa densa
model_DA.add(Dense(units=1000, activation="relu"))

#capa de salida
model_DA.add(Dense(units=100, activation="softmax"))

# %%
model_DA.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)       295168
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)       590080
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_3 (Dense)             (None, 1000)              8193000
#
#  dense_4 (Dense)             (None, 1000)              1001000
#
#  dense_5 (Dense)             (None, 100)               100100
#
# =================================================================
# Total params: 13870484 (52.91 MB)
# Trainable params: 13870484 (52.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer_DA = keras.optimizers.Nadam(learning_rate=0.0001)

#model compiling
model_DA.compile(optimizer=optimizer_DA, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#early stopping
early_stop_DA = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

#model checkpoint para guardar el mejor modelo
model_checkpoint_DA = ModelCheckpoint('CheckPoint_DataAug.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# %% [markdown]
# Se aplica el parámetro `rotation_range` para provocar una rotación de 20º y horizontal flip para voltear la imagen a lo largo del eje horizontal. Estos cambios se aplican a todas las imágenes de entrenamiento.

# %%
data_gen = ImageDataGenerator(
            rotation_range=20,
    horizontal_flip=True)

data_gen.fit(train_x, seed = 123)

# %%
# Entrenamiento del modelo
import time
history_DA = model_DA.fit(data_gen.flow(train_x,train_y,
                    batch_size=batch_size,
                    seed=123),
                    epochs=epochs,
                    steps_per_epoch=train_x.shape[0] // batch_size,
                    validation_data=(val_x, val_y),
                    callbacks=[early_stop_DA, model_checkpoint_DA],
                    verbose=1)
training_stop = time.time()
training_time = training_stop - training_start
print(f"Training time: {training_time}")
# Out:
# Epoch 1/100
# 625/625 [==============================] - ETA: 0s - loss: 3.9819 - accuracy: 0.0919
# Epoch 1: val_loss improved from inf to 3.45311, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 41s 60ms/step - loss: 3.9819 - accuracy: 0.0919 - val_loss: 3.4531 - val_accuracy: 0.1804
# Epoch 2/100
# 625/625 [==============================] - ETA: 0s - loss: 3.2290 - accuracy: 0.2141
# Epoch 2: val_loss improved from 3.45311 to 3.00432, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 33s 53ms/step - loss: 3.2290 - accuracy: 0.2141 - val_loss: 3.0043 - val_accuracy: 0.2594
# Epoch 3/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.8414 - accuracy: 0.2909
# Epoch 3: val_loss improved from 3.00432 to 2.81423, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 38s 61ms/step - loss: 2.8415 - accuracy: 0.2908 - val_loss: 2.8142 - val_accuracy: 0.2979
# Epoch 4/100
# 625/625 [==============================] - ETA: 0s - loss: 2.5646 - accuracy: 0.3469
# Epoch 4: val_loss improved from 2.81423 to 2.72461, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 33s 52ms/step - loss: 2.5646 - accuracy: 0.3469 - val_loss: 2.7246 - val_accuracy: 0.3216
# Epoch 5/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.3244 - accuracy: 0.3981
# Epoch 5: val_loss improved from 2.72461 to 2.55402, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 32s 51ms/step - loss: 2.3240 - accuracy: 0.3981 - val_loss: 2.5540 - val_accuracy: 0.3579
# Epoch 6/100
# 624/625 [============================>.] - ETA: 0s - loss: 2.1141 - accuracy: 0.4437
# Epoch 6: val_loss improved from 2.55402 to 2.43624, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 32s 51ms/step - loss: 2.1141 - accuracy: 0.4436 - val_loss: 2.4362 - val_accuracy: 0.3829
# Epoch 7/100
# 625/625 [==============================] - ETA: 0s - loss: 1.9155 - accuracy: 0.4879
# Epoch 7: val_loss improved from 2.43624 to 2.40264, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 33s 52ms/step - loss: 1.9155 - accuracy: 0.4879 - val_loss: 2.4026 - val_accuracy: 0.4005
# Epoch 8/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.7260 - accuracy: 0.5337
# Epoch 8: val_loss improved from 2.40264 to 2.39679, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 32s 51ms/step - loss: 1.7261 - accuracy: 0.5337 - val_loss: 2.3968 - val_accuracy: 0.4142
# Epoch 9/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.5380 - accuracy: 0.5789
# Epoch 9: val_loss did not improve from 2.39679
# 625/625 [==============================] - 32s 51ms/step - loss: 1.5373 - accuracy: 0.5791 - val_loss: 2.4881 - val_accuracy: 0.4139
# Epoch 10/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.3503 - accuracy: 0.6252
# Epoch 10: val_loss improved from 2.39679 to 2.35532, saving model to CheckPoint_DataAug.h5
# 625/625 [==============================] - 37s 59ms/step - loss: 1.3507 - accuracy: 0.6251 - val_loss: 2.3553 - val_accuracy: 0.4303
# Epoch 11/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.1841 - accuracy: 0.6700
# Epoch 11: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 1.1838 - accuracy: 0.6701 - val_loss: 2.5037 - val_accuracy: 0.4366
# Epoch 12/100
# 624/625 [============================>.] - ETA: 0s - loss: 1.0155 - accuracy: 0.7113
# Epoch 12: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 1.0156 - accuracy: 0.7111 - val_loss: 2.6761 - val_accuracy: 0.4349
# Epoch 13/100
# 624/625 [============================>.] - ETA: 0s - loss: 0.8648 - accuracy: 0.7512
# Epoch 13: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 52ms/step - loss: 0.8652 - accuracy: 0.7512 - val_loss: 2.7675 - val_accuracy: 0.4388
# Epoch 14/100
# 625/625 [==============================] - ETA: 0s - loss: 0.7501 - accuracy: 0.7810
# Epoch 14: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.7501 - accuracy: 0.7810 - val_loss: 2.9568 - val_accuracy: 0.4290
# Epoch 15/100
# 625/625 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.8152
# Epoch 15: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6283 - accuracy: 0.8152 - val_loss: 3.0417 - val_accuracy: 0.4278
# Epoch 16/100
# 624/625 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.8394
# Epoch 16: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5414 - accuracy: 0.8394 - val_loss: 3.2220 - val_accuracy: 0.4344
# Epoch 17/100
# 625/625 [==============================] - ETA: 0s - loss: 0.4737 - accuracy: 0.8581
# Epoch 17: val_loss did not improve from 2.35532
# 625/625 [==============================] - 31s 50ms/step - loss: 0.4737 - accuracy: 0.8581 - val_loss: 3.3223 - val_accuracy: 0.4347
# Epoch 18/100
# 624/625 [============================>.] - ETA: 0s - loss: 0.4116 - accuracy: 0.8760
# Epoch 18: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.4117 - accuracy: 0.8759 - val_loss: 3.6735 - val_accuracy: 0.4169
# Epoch 19/100
# 625/625 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8890
# Epoch 19: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.3677 - accuracy: 0.8890 - val_loss: 3.6027 - val_accuracy: 0.4336
# Epoch 20/100
# 625/625 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.9021
# Epoch 20: val_loss did not improve from 2.35532
# 625/625 [==============================] - 31s 50ms/step - loss: 0.3180 - accuracy: 0.9021 - val_loss: 3.7164 - val_accuracy: 0.4264
# Epoch 21/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2976 - accuracy: 0.9106
# Epoch 21: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.2976 - accuracy: 0.9106 - val_loss: 3.7530 - val_accuracy: 0.4334
# Epoch 22/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9181
# Epoch 22: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 50ms/step - loss: 0.2666 - accuracy: 0.9181 - val_loss: 3.9733 - val_accuracy: 0.4216
# Epoch 23/100
# 624/625 [============================>.] - ETA: 0s - loss: 0.2558 - accuracy: 0.9217
# Epoch 23: val_loss did not improve from 2.35532
# 625/625 [==============================] - 31s 50ms/step - loss: 0.2557 - accuracy: 0.9218 - val_loss: 3.7407 - val_accuracy: 0.4314
# Epoch 24/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9309
# Epoch 24: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.2232 - accuracy: 0.9309 - val_loss: 4.2582 - val_accuracy: 0.4331
# Epoch 25/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9339
# Epoch 25: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.2174 - accuracy: 0.9339 - val_loss: 4.0557 - val_accuracy: 0.4312
# Epoch 26/100
# 625/625 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9366
# Epoch 26: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.2043 - accuracy: 0.9366 - val_loss: 4.0997 - val_accuracy: 0.4298
# Epoch 27/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9402
# Epoch 27: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.1918 - accuracy: 0.9402 - val_loss: 4.2029 - val_accuracy: 0.4372
# Epoch 28/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9423
# Epoch 28: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 50ms/step - loss: 0.1841 - accuracy: 0.9423 - val_loss: 4.3615 - val_accuracy: 0.4271
# Epoch 29/100
# 625/625 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9467
# Epoch 29: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.1694 - accuracy: 0.9467 - val_loss: 4.5302 - val_accuracy: 0.4285
# Epoch 30/100
# 624/625 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.9486
# Epoch 30: val_loss did not improve from 2.35532
# 625/625 [==============================] - 32s 51ms/step - loss: 0.1651 - accuracy: 0.9486 - val_loss: 4.5039 - val_accuracy: 0.4305
# Epoch 30: early stopping
# Training time: 1708.869987487793

# %%
HISTORY.append(history_DA)

# %%
# Visualize training process
training_plot(history_DA)

# %% [markdown]
# De las gráficas se observa que el modelo, a partir de la época 20, obtiene una precisión elevada (o una pérdida muy baja) con los datos de entrenamiento. A parte, de los datos de validación se observa que el modelo converje hacia una precisión del ~40% y que antes de la época 10 el modelo vuelve a sobreentrenar.
#
# Todo esto significa que el modelo se está acoplando demasiado rápido a los datos de entrenamiento y no esta permitiendo converjer adecuadamente con los datos de validación.

# %% [markdown]
# ####Rendimiento

# %%
scores_DA = model_DA.evaluate(test_data, test_labels)
TEST_LOSS.append(scores_DA[0])
TEST_ACC.append(scores_DA[1])

print(f'accuracy on test set: {model_DA.metrics_names[1]} of {scores_DA[1]*100}')
# Out:
# 313/313 [==============================] - 2s 8ms/step - loss: 4.3796 - accuracy: 0.4440
# accuracy on test set: accuracy of 44.40000057220459

# %% [markdown]
# Con los datos anteriormente descritos se obtienen los siguientes valores:
# *   Tiempo de ejecución: ~1708 s en 30 epochs.
# *   Precisión con los datos de test: ~45%

# %% [markdown]
# ##Modelo Optimizado con Data Augmentation

# %% [markdown]
# ###Optimizadores
#
# **Dropout** se utiliza como una técnica de regularización cuyo objetivo es evitar el sobreajuste al garantizar que ninguna unidad sea codependiente.
#
# Consiste en consiste en retirar (poner a cero) aleatoriamente un número de características de salida de la capa durante el entrenamiento. En cada epoch cada neurona tiene una tasa o probabilidad de estar inactiva. La “tasa de dropout” es la fracción de características que se ponen a 0 (entre 0.2 a 0.5).
#
# **Batch Normalization** es uno de los métodos diseñados para evitar problemas en el descenso estocástico del gradiente a través de la normalización de los inputs de las capas y su posterior transformación. Para ello Batch Normalization actúa como una capa donde realiza 2 acciones:
#
# Normaliza los valores introducidos.
#
# zi=γ⊗x^i+β  donde
#
# γ  es un factor escalar (inicializado como 1).
#
# β  es un factor de compensación (inicializado como 0).
#
# Ventajas:
#
# *   Vuelve la red más rápida y estable
# *   Se logra mayor precisión en la red en menos epochs lo que puede desembocar en un mayor rendimiento de este si se mantiene el número inicial de epochs.

# %% [markdown]
# El **Dropout** se ha utilizado en todas las capas con valor de 0.2 en la capa de entrada y 0.5 en el resto de capas. La configuración configuración de 0.2 y 0,5 funciona bien y escomputacionalmente eficiente.
#
# La elección de dropout con valor de 0.2 en la primera capa convolucional es debido a que al usar un valor de 0.5 el modelo obtiene menos precisión. Esto ocurre ya que al suprimir la mitad de parámetros en la primera capa estamos impidiendo que se traslade toda la información de forma adecuada.
#
# La utilizción de Batch Normalization no suponía una mejora de rendimiendo en el modelo planteado. Por tanto, en este modelo no aparecerá utilizada.

# %% [markdown]
# ###Modelo

# %%
#Modelo Optimizado
model_op = Sequential()

#Pila 1
#convolucion
model_op.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu", input_shape=(32,32,3)))
model_op.add(Conv2D(filters=128, kernel_size=3, padding="same", activation="relu"))
#pooling
model_op.add(MaxPool2D(pool_size=2, strides=2))
#dropout
model_op.add(Dropout(0.2))

#Pila 2
#convolución
model_op.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
model_op.add(Conv2D(filters=256, kernel_size=3, padding="same", activation="relu"))
#pooling
model_op.add(MaxPool2D(pool_size=2, strides=2))
#dropout
model_op.add(Dropout(0.5))

#Pila 3
#convolución
model_op.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
model_op.add(Conv2D(filters=512, kernel_size=3, padding="same", activation="relu"))
#pooling
model_op.add(MaxPool2D(pool_size=2, strides=2))
#dropout
model_op.add(Dropout(0.5))

#flattening
model_op.add(Flatten())

#1º Capa densa
model_op.add(Dense(units=1000, activation="relu"))
#dropout
model_op.add(Dropout(0.5))

# 2ºCapa densa
model_op.add(Dense(units=1000, activation="relu"))
#dropout
model_op.add(Dropout(0.5))

#output layer
model_op.add(Dense(units=100, activation="softmax"))

# %%
model_op.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       3584
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)       295168
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)       590080
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 512)         0
#
#  flatten_2 (Flatten)         (None, 8192)              0
#
#  dense_6 (Dense)             (None, 1000)              8193000
#
#  dropout_3 (Dropout)         (None, 1000)              0
#
#  dense_7 (Dense)             (None, 1000)              1001000
#
#  dropout_4 (Dropout)         (None, 1000)              0
#
#  dense_8 (Dense)             (None, 100)               100100
#
# =================================================================
# Total params: 13870484 (52.91 MB)
# Trainable params: 13870484 (52.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Explicación suma de parámetros**
# La capa convolucional va recorriendo la imagen en ventanas de 3x3 creando así una capa oculta de 30x30 (32 píxeles - 3 de las ventanas + 1 de la primera iteración) y un padding de "same" para preservar las dimensiones de la imagen original. El cálculo de parámetros se hará con la siguiente fórmula: parámetros = (tamaño del kernel(largo) x tamaño del kernel(ancho) x número de canales de entrada + 1) x número de filtros. Con esta fórmula nuestra primera capa convolucional tendrá los siguientes parámetros: (3 x 3 x 3 + 1) x 128 = 3584.
# Nuestra segunda capa convolucional tendrá la siguiente cantidad de parámetros: (3 x 3 x 128(número de canales de entrada proveniente de la capa anterior) + 1) x 128 = 147584.
# La tercera tendrá: (3 x 3 x 128 + 1) x 256 = 295168.
# La cuarta tendrá: (3 x 3 x 256 + 1) x 256 = 590080.
# La quinta tendrá: (3 x 3 x 256 + 1) x 512 = 1180160.
# La sexta tendrá: (3 x 3 x 512 + 1) x 512 = 2359808.
# Para el calculo de parámetros de la capa densa seguiremos la siguiente fórmula: Parámetros=(Entradas + 1) × neuronas. En nuestro caso será: (8192 + 1) x 1000 = 8193000. Para nuestra segunda capa densa el cálculo será:  (1000 + 1) x 1000 = 1001000. Para nuestra tercera capa densa el cálculo será: (1001 + 1) x 100 = 100100. El resultado total de los parámetros será la suma de lo calculado anteriormente.

# %% [markdown]
# Para este modelo se aumentan tanto el número de epochs a 130 así como la paciencia a 25 en EarlyStopping otorgándole más grados de libertad en el entrenamiento para obtener el modelo más optimizado posible.

# %%
epochs_op = 130
batch_size_op = 64
optimizer_op = keras.optimizers.Nadam(learning_rate=0.0001)

#model compiling
model_op.compile(optimizer=optimizer_op, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#early stopping
early_stop_op = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

#model checkpoint para guardar el mejor modelo
model_checkpoint_op = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# %%
#Aumento de las imagenes de entrenamiento
data_gen = ImageDataGenerator(
            rotation_range=20,
    horizontal_flip=True)

# %%
data_gen.fit(train_x, seed = 123)

# %%
import time
history_op = model_op.fit(data_gen.flow(train_x,train_y,
                    batch_size=batch_size_op,
                    seed=123),
                    epochs=epochs_op,
                    steps_per_epoch=train_x.shape[0] // batch_size_op,
                    validation_data=(val_x, val_y),
                    callbacks=[early_stop_op, model_checkpoint_op],
                    verbose=1)
training_stop = time.time()
training_time = training_stop - training_start
print(f"Training time: {training_time}")
# Out:
# Epoch 1/130
# 624/625 [============================>.] - ETA: 0s - loss: 4.5231 - accuracy: 0.0161
# Epoch 1: val_loss improved from inf to 4.46514, saving model to best_model.h5
# 625/625 [==============================] - 38s 53ms/step - loss: 4.5231 - accuracy: 0.0161 - val_loss: 4.4651 - val_accuracy: 0.0219
# Epoch 2/130
# 625/625 [==============================] - ETA: 0s - loss: 4.2801 - accuracy: 0.0350
# Epoch 2: val_loss improved from 4.46514 to 4.02474, saving model to best_model.h5
# 625/625 [==============================] - 35s 56ms/step - loss: 4.2801 - accuracy: 0.0350 - val_loss: 4.0247 - val_accuracy: 0.0738
# Epoch 3/130
# 624/625 [============================>.] - ETA: 0s - loss: 3.9484 - accuracy: 0.0796
# Epoch 3: val_loss improved from 4.02474 to 3.67798, saving model to best_model.h5
# 625/625 [==============================] - 33s 53ms/step - loss: 3.9484 - accuracy: 0.0797 - val_loss: 3.6780 - val_accuracy: 0.1257
# Epoch 4/130
# 625/625 [==============================] - ETA: 0s - loss: 3.6790 - accuracy: 0.1216
# Epoch 4: val_loss improved from 3.67798 to 3.36585, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 3.6790 - accuracy: 0.1216 - val_loss: 3.3658 - val_accuracy: 0.1804
# Epoch 5/130
# 624/625 [============================>.] - ETA: 0s - loss: 3.4605 - accuracy: 0.1571
# Epoch 5: val_loss improved from 3.36585 to 3.13767, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 3.4606 - accuracy: 0.1570 - val_loss: 3.1377 - val_accuracy: 0.2214
# Epoch 6/130
# 625/625 [==============================] - ETA: 0s - loss: 3.2747 - accuracy: 0.1898
# Epoch 6: val_loss improved from 3.13767 to 2.94683, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 3.2747 - accuracy: 0.1898 - val_loss: 2.9468 - val_accuracy: 0.2585
# Epoch 7/130
# 625/625 [==============================] - ETA: 0s - loss: 3.1172 - accuracy: 0.2232
# Epoch 7: val_loss improved from 2.94683 to 2.81270, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 3.1172 - accuracy: 0.2232 - val_loss: 2.8127 - val_accuracy: 0.2886
# Epoch 8/130
# 625/625 [==============================] - ETA: 0s - loss: 2.9763 - accuracy: 0.2506
# Epoch 8: val_loss improved from 2.81270 to 2.65494, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 2.9763 - accuracy: 0.2506 - val_loss: 2.6549 - val_accuracy: 0.3154
# Epoch 9/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.8662 - accuracy: 0.2713
# Epoch 9: val_loss did not improve from 2.65494
# 625/625 [==============================] - 33s 53ms/step - loss: 2.8664 - accuracy: 0.2713 - val_loss: 2.6695 - val_accuracy: 0.3173
# Epoch 10/130
# 625/625 [==============================] - ETA: 0s - loss: 2.7536 - accuracy: 0.2944
# Epoch 10: val_loss improved from 2.65494 to 2.51969, saving model to best_model.h5
# 625/625 [==============================] - 39s 63ms/step - loss: 2.7536 - accuracy: 0.2944 - val_loss: 2.5197 - val_accuracy: 0.3480
# Epoch 11/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.6612 - accuracy: 0.3124
# Epoch 11: val_loss improved from 2.51969 to 2.43881, saving model to best_model.h5
# 625/625 [==============================] - 33s 53ms/step - loss: 2.6610 - accuracy: 0.3124 - val_loss: 2.4388 - val_accuracy: 0.3620
# Epoch 12/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.5609 - accuracy: 0.3366
# Epoch 12: val_loss improved from 2.43881 to 2.35725, saving model to best_model.h5
# 625/625 [==============================] - 38s 60ms/step - loss: 2.5603 - accuracy: 0.3367 - val_loss: 2.3573 - val_accuracy: 0.3853
# Epoch 13/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.4926 - accuracy: 0.3486
# Epoch 13: val_loss improved from 2.35725 to 2.24592, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 2.4927 - accuracy: 0.3486 - val_loss: 2.2459 - val_accuracy: 0.4054
# Epoch 14/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.4192 - accuracy: 0.3679
# Epoch 14: val_loss improved from 2.24592 to 2.21050, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 2.4188 - accuracy: 0.3679 - val_loss: 2.2105 - val_accuracy: 0.4137
# Epoch 15/130
# 625/625 [==============================] - ETA: 0s - loss: 2.3394 - accuracy: 0.3814
# Epoch 15: val_loss improved from 2.21050 to 2.09239, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 2.3394 - accuracy: 0.3814 - val_loss: 2.0924 - val_accuracy: 0.4358
# Epoch 16/130
# 625/625 [==============================] - ETA: 0s - loss: 2.2794 - accuracy: 0.3952
# Epoch 16: val_loss improved from 2.09239 to 2.09089, saving model to best_model.h5
# 625/625 [==============================] - 36s 58ms/step - loss: 2.2794 - accuracy: 0.3952 - val_loss: 2.0909 - val_accuracy: 0.4381
# Epoch 17/130
# 625/625 [==============================] - ETA: 0s - loss: 2.2330 - accuracy: 0.4053
# Epoch 17: val_loss improved from 2.09089 to 2.05648, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 2.2330 - accuracy: 0.4053 - val_loss: 2.0565 - val_accuracy: 0.4440
# Epoch 18/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.1673 - accuracy: 0.4211
# Epoch 18: val_loss improved from 2.05648 to 2.02619, saving model to best_model.h5
# 625/625 [==============================] - 33s 53ms/step - loss: 2.1672 - accuracy: 0.4212 - val_loss: 2.0262 - val_accuracy: 0.4563
# Epoch 19/130
# 625/625 [==============================] - ETA: 0s - loss: 2.1144 - accuracy: 0.4314
# Epoch 19: val_loss improved from 2.02619 to 1.99969, saving model to best_model.h5
# 625/625 [==============================] - 38s 61ms/step - loss: 2.1144 - accuracy: 0.4314 - val_loss: 1.9997 - val_accuracy: 0.4624
# Epoch 20/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.0593 - accuracy: 0.4412
# Epoch 20: val_loss did not improve from 1.99969
# 625/625 [==============================] - 33s 53ms/step - loss: 2.0590 - accuracy: 0.4411 - val_loss: 2.0089 - val_accuracy: 0.4620
# Epoch 21/130
# 624/625 [============================>.] - ETA: 0s - loss: 2.0043 - accuracy: 0.4573
# Epoch 21: val_loss improved from 1.99969 to 1.89494, saving model to best_model.h5
# 625/625 [==============================] - 39s 63ms/step - loss: 2.0039 - accuracy: 0.4572 - val_loss: 1.8949 - val_accuracy: 0.4825
# Epoch 22/130
# 625/625 [==============================] - ETA: 0s - loss: 1.9664 - accuracy: 0.4665
# Epoch 22: val_loss did not improve from 1.89494
# 625/625 [==============================] - 34s 54ms/step - loss: 1.9664 - accuracy: 0.4665 - val_loss: 1.8996 - val_accuracy: 0.4854
# Epoch 23/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.9278 - accuracy: 0.4778
# Epoch 23: val_loss improved from 1.89494 to 1.80939, saving model to best_model.h5
# 625/625 [==============================] - 36s 58ms/step - loss: 1.9278 - accuracy: 0.4779 - val_loss: 1.8094 - val_accuracy: 0.5067
# Epoch 24/130
# 625/625 [==============================] - ETA: 0s - loss: 1.8824 - accuracy: 0.4822
# Epoch 24: val_loss did not improve from 1.80939
# 625/625 [==============================] - 34s 54ms/step - loss: 1.8824 - accuracy: 0.4822 - val_loss: 1.9176 - val_accuracy: 0.4848
# Epoch 25/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.8474 - accuracy: 0.4949
# Epoch 25: val_loss improved from 1.80939 to 1.76697, saving model to best_model.h5
# 625/625 [==============================] - 38s 61ms/step - loss: 1.8474 - accuracy: 0.4948 - val_loss: 1.7670 - val_accuracy: 0.5134
# Epoch 26/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.8158 - accuracy: 0.5012
# Epoch 26: val_loss improved from 1.76697 to 1.75747, saving model to best_model.h5
# 625/625 [==============================] - 34s 55ms/step - loss: 1.8163 - accuracy: 0.5011 - val_loss: 1.7575 - val_accuracy: 0.5180
# Epoch 27/130
# 625/625 [==============================] - ETA: 0s - loss: 1.7710 - accuracy: 0.5103
# Epoch 27: val_loss improved from 1.75747 to 1.74723, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 1.7710 - accuracy: 0.5103 - val_loss: 1.7472 - val_accuracy: 0.5214
# Epoch 28/130
# 625/625 [==============================] - ETA: 0s - loss: 1.7398 - accuracy: 0.5200
# Epoch 28: val_loss improved from 1.74723 to 1.71696, saving model to best_model.h5
# 625/625 [==============================] - 35s 56ms/step - loss: 1.7398 - accuracy: 0.5200 - val_loss: 1.7170 - val_accuracy: 0.5270
# Epoch 29/130
# 625/625 [==============================] - ETA: 0s - loss: 1.7055 - accuracy: 0.5269
# Epoch 29: val_loss improved from 1.71696 to 1.71458, saving model to best_model.h5
# 625/625 [==============================] - 33s 53ms/step - loss: 1.7055 - accuracy: 0.5269 - val_loss: 1.7146 - val_accuracy: 0.5262
# Epoch 30/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.6693 - accuracy: 0.5374
# Epoch 30: val_loss improved from 1.71458 to 1.69946, saving model to best_model.h5
# 625/625 [==============================] - 34s 55ms/step - loss: 1.6688 - accuracy: 0.5375 - val_loss: 1.6995 - val_accuracy: 0.5355
# Epoch 31/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.6356 - accuracy: 0.5433
# Epoch 31: val_loss improved from 1.69946 to 1.66562, saving model to best_model.h5
# 625/625 [==============================] - 34s 55ms/step - loss: 1.6354 - accuracy: 0.5432 - val_loss: 1.6656 - val_accuracy: 0.5431
# Epoch 32/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.6102 - accuracy: 0.5506
# Epoch 32: val_loss improved from 1.66562 to 1.65966, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 1.6102 - accuracy: 0.5505 - val_loss: 1.6597 - val_accuracy: 0.5432
# Epoch 33/130
# 625/625 [==============================] - ETA: 0s - loss: 1.5885 - accuracy: 0.5554
# Epoch 33: val_loss improved from 1.65966 to 1.65409, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 1.5885 - accuracy: 0.5554 - val_loss: 1.6541 - val_accuracy: 0.5460
# Epoch 34/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.5566 - accuracy: 0.5631
# Epoch 34: val_loss did not improve from 1.65409
# 625/625 [==============================] - 33s 53ms/step - loss: 1.5561 - accuracy: 0.5631 - val_loss: 1.6644 - val_accuracy: 0.5445
# Epoch 35/130
# 625/625 [==============================] - ETA: 0s - loss: 1.5321 - accuracy: 0.5661
# Epoch 35: val_loss improved from 1.65409 to 1.64582, saving model to best_model.h5
# 625/625 [==============================] - 39s 62ms/step - loss: 1.5321 - accuracy: 0.5661 - val_loss: 1.6458 - val_accuracy: 0.5515
# Epoch 36/130
# 625/625 [==============================] - ETA: 0s - loss: 1.5093 - accuracy: 0.5706
# Epoch 36: val_loss improved from 1.64582 to 1.63834, saving model to best_model.h5
# 625/625 [==============================] - 34s 55ms/step - loss: 1.5093 - accuracy: 0.5706 - val_loss: 1.6383 - val_accuracy: 0.5484
# Epoch 37/130
# 625/625 [==============================] - ETA: 0s - loss: 1.4746 - accuracy: 0.5822
# Epoch 37: val_loss did not improve from 1.63834
# 625/625 [==============================] - 33s 53ms/step - loss: 1.4746 - accuracy: 0.5822 - val_loss: 1.6888 - val_accuracy: 0.5509
# Epoch 38/130
# 625/625 [==============================] - ETA: 0s - loss: 1.4594 - accuracy: 0.5864
# Epoch 38: val_loss improved from 1.63834 to 1.58812, saving model to best_model.h5
# 625/625 [==============================] - 38s 61ms/step - loss: 1.4594 - accuracy: 0.5864 - val_loss: 1.5881 - val_accuracy: 0.5640
# Epoch 39/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.4303 - accuracy: 0.5919
# Epoch 39: val_loss improved from 1.58812 to 1.55495, saving model to best_model.h5
# 625/625 [==============================] - 34s 54ms/step - loss: 1.4301 - accuracy: 0.5918 - val_loss: 1.5550 - val_accuracy: 0.5697
# Epoch 40/130
# 625/625 [==============================] - ETA: 0s - loss: 1.3988 - accuracy: 0.5988
# Epoch 40: val_loss did not improve from 1.55495
# 625/625 [==============================] - 34s 55ms/step - loss: 1.3988 - accuracy: 0.5988 - val_loss: 1.5765 - val_accuracy: 0.5716
# Epoch 41/130
# 625/625 [==============================] - ETA: 0s - loss: 1.3950 - accuracy: 0.5971
# Epoch 41: val_loss did not improve from 1.55495
# 625/625 [==============================] - 34s 54ms/step - loss: 1.3950 - accuracy: 0.5971 - val_loss: 1.6036 - val_accuracy: 0.5628
# Epoch 42/130
# 625/625 [==============================] - ETA: 0s - loss: 1.3599 - accuracy: 0.6114
# Epoch 42: val_loss improved from 1.55495 to 1.53517, saving model to best_model.h5
# 625/625 [==============================] - 39s 62ms/step - loss: 1.3599 - accuracy: 0.6114 - val_loss: 1.5352 - val_accuracy: 0.5748
# Epoch 43/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.3396 - accuracy: 0.6164
# Epoch 43: val_loss did not improve from 1.53517
# 625/625 [==============================] - 33s 53ms/step - loss: 1.3391 - accuracy: 0.6166 - val_loss: 1.5821 - val_accuracy: 0.5667
# Epoch 44/130
# 625/625 [==============================] - ETA: 0s - loss: 1.3203 - accuracy: 0.6196
# Epoch 44: val_loss did not improve from 1.53517
# 625/625 [==============================] - 33s 53ms/step - loss: 1.3203 - accuracy: 0.6196 - val_loss: 1.5513 - val_accuracy: 0.5767
# Epoch 45/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.2937 - accuracy: 0.6280
# Epoch 45: val_loss did not improve from 1.53517
# 625/625 [==============================] - 34s 54ms/step - loss: 1.2939 - accuracy: 0.6280 - val_loss: 1.5487 - val_accuracy: 0.5779
# Epoch 46/130
# 625/625 [==============================] - ETA: 0s - loss: 1.2758 - accuracy: 0.6296
# Epoch 46: val_loss improved from 1.53517 to 1.52372, saving model to best_model.h5
# 625/625 [==============================] - 40s 63ms/step - loss: 1.2758 - accuracy: 0.6296 - val_loss: 1.5237 - val_accuracy: 0.5805
# Epoch 47/130
# 625/625 [==============================] - ETA: 0s - loss: 1.2608 - accuracy: 0.6372
# Epoch 47: val_loss improved from 1.52372 to 1.50167, saving model to best_model.h5
# 625/625 [==============================] - 34s 55ms/step - loss: 1.2608 - accuracy: 0.6372 - val_loss: 1.5017 - val_accuracy: 0.5891
# Epoch 48/130
# 625/625 [==============================] - ETA: 0s - loss: 1.2356 - accuracy: 0.6406
# Epoch 48: val_loss did not improve from 1.50167
# 625/625 [==============================] - 33s 53ms/step - loss: 1.2356 - accuracy: 0.6406 - val_loss: 1.5454 - val_accuracy: 0.5777
# Epoch 49/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.2174 - accuracy: 0.6438
# Epoch 49: val_loss did not improve from 1.50167
# 625/625 [==============================] - 34s 54ms/step - loss: 1.2175 - accuracy: 0.6436 - val_loss: 1.5479 - val_accuracy: 0.5843
# Epoch 50/130
# 625/625 [==============================] - ETA: 0s - loss: 1.2039 - accuracy: 0.6472
# Epoch 50: val_loss did not improve from 1.50167
# 625/625 [==============================] - 34s 54ms/step - loss: 1.2039 - accuracy: 0.6472 - val_loss: 1.5175 - val_accuracy: 0.5866
# Epoch 51/130
# 625/625 [==============================] - ETA: 0s - loss: 1.1847 - accuracy: 0.6550
# Epoch 51: val_loss did not improve from 1.50167
# 625/625 [==============================] - 33s 53ms/step - loss: 1.1847 - accuracy: 0.6550 - val_loss: 1.5363 - val_accuracy: 0.5847
# Epoch 52/130
# 625/625 [==============================] - ETA: 0s - loss: 1.1721 - accuracy: 0.6574
# Epoch 52: val_loss did not improve from 1.50167
# 625/625 [==============================] - 33s 53ms/step - loss: 1.1721 - accuracy: 0.6574 - val_loss: 1.5262 - val_accuracy: 0.5873
# Epoch 53/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.1532 - accuracy: 0.6622
# Epoch 53: val_loss improved from 1.50167 to 1.48589, saving model to best_model.h5
# 625/625 [==============================] - 39s 63ms/step - loss: 1.1534 - accuracy: 0.6621 - val_loss: 1.4859 - val_accuracy: 0.5984
# Epoch 54/130
# 625/625 [==============================] - ETA: 0s - loss: 1.1398 - accuracy: 0.6673
# Epoch 54: val_loss did not improve from 1.48589
# 625/625 [==============================] - 33s 53ms/step - loss: 1.1398 - accuracy: 0.6673 - val_loss: 1.5140 - val_accuracy: 0.5935
# Epoch 55/130
# 625/625 [==============================] - ETA: 0s - loss: 1.1258 - accuracy: 0.6678
# Epoch 55: val_loss improved from 1.48589 to 1.46429, saving model to best_model.h5
# 625/625 [==============================] - 41s 65ms/step - loss: 1.1258 - accuracy: 0.6678 - val_loss: 1.4643 - val_accuracy: 0.6004
# Epoch 56/130
# 625/625 [==============================] - ETA: 0s - loss: 1.1075 - accuracy: 0.6752
# Epoch 56: val_loss did not improve from 1.46429
# 625/625 [==============================] - 35s 56ms/step - loss: 1.1075 - accuracy: 0.6752 - val_loss: 1.5316 - val_accuracy: 0.5985
# Epoch 57/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0908 - accuracy: 0.6764
# Epoch 57: val_loss did not improve from 1.46429
# 625/625 [==============================] - 34s 55ms/step - loss: 1.0908 - accuracy: 0.6764 - val_loss: 1.4972 - val_accuracy: 0.5941
# Epoch 58/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0814 - accuracy: 0.6792
# Epoch 58: val_loss did not improve from 1.46429
# 625/625 [==============================] - 34s 55ms/step - loss: 1.0814 - accuracy: 0.6792 - val_loss: 1.4782 - val_accuracy: 0.5984
# Epoch 59/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0701 - accuracy: 0.6836
# Epoch 59: val_loss did not improve from 1.46429
# 625/625 [==============================] - 33s 53ms/step - loss: 1.0701 - accuracy: 0.6836 - val_loss: 1.5166 - val_accuracy: 0.5939
# Epoch 60/130
# 624/625 [============================>.] - ETA: 0s - loss: 1.0515 - accuracy: 0.6876
# Epoch 60: val_loss did not improve from 1.46429
# 625/625 [==============================] - 35s 56ms/step - loss: 1.0512 - accuracy: 0.6877 - val_loss: 1.5225 - val_accuracy: 0.5950
# Epoch 61/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0328 - accuracy: 0.6947
# Epoch 61: val_loss did not improve from 1.46429
# 625/625 [==============================] - 34s 54ms/step - loss: 1.0328 - accuracy: 0.6947 - val_loss: 1.5140 - val_accuracy: 0.5958
# Epoch 62/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0194 - accuracy: 0.6987
# Epoch 62: val_loss did not improve from 1.46429
# 625/625 [==============================] - 35s 57ms/step - loss: 1.0194 - accuracy: 0.6987 - val_loss: 1.5002 - val_accuracy: 0.6016
# Epoch 63/130
# 625/625 [==============================] - ETA: 0s - loss: 1.0108 - accuracy: 0.6988
# Epoch 63: val_loss improved from 1.46429 to 1.44318, saving model to best_model.h5
# 625/625 [==============================] - 40s 63ms/step - loss: 1.0108 - accuracy: 0.6988 - val_loss: 1.4432 - val_accuracy: 0.6104
# Epoch 64/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.9887 - accuracy: 0.7062
# Epoch 64: val_loss did not improve from 1.44318
# 625/625 [==============================] - 34s 55ms/step - loss: 0.9895 - accuracy: 0.7061 - val_loss: 1.5010 - val_accuracy: 0.6049
# Epoch 65/130
# 625/625 [==============================] - ETA: 0s - loss: 0.9778 - accuracy: 0.7099
# Epoch 65: val_loss did not improve from 1.44318
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9778 - accuracy: 0.7099 - val_loss: 1.4916 - val_accuracy: 0.6013
# Epoch 66/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.9678 - accuracy: 0.7110
# Epoch 66: val_loss did not improve from 1.44318
# 625/625 [==============================] - 34s 55ms/step - loss: 0.9680 - accuracy: 0.7110 - val_loss: 1.4560 - val_accuracy: 0.6077
# Epoch 67/130
# 625/625 [==============================] - ETA: 0s - loss: 0.9530 - accuracy: 0.7128
# Epoch 67: val_loss improved from 1.44318 to 1.43717, saving model to best_model.h5
# 625/625 [==============================] - 39s 62ms/step - loss: 0.9530 - accuracy: 0.7128 - val_loss: 1.4372 - val_accuracy: 0.6166
# Epoch 68/130
# 625/625 [==============================] - ETA: 0s - loss: 0.9520 - accuracy: 0.7161
# Epoch 68: val_loss did not improve from 1.43717
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9520 - accuracy: 0.7161 - val_loss: 1.4960 - val_accuracy: 0.6036
# Epoch 69/130
# 625/625 [==============================] - ETA: 0s - loss: 0.9442 - accuracy: 0.7157
# Epoch 69: val_loss improved from 1.43717 to 1.41344, saving model to best_model.h5
# 625/625 [==============================] - 40s 63ms/step - loss: 0.9442 - accuracy: 0.7157 - val_loss: 1.4134 - val_accuracy: 0.6180
# Epoch 70/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.9275 - accuracy: 0.7200
# Epoch 70: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9273 - accuracy: 0.7200 - val_loss: 1.5273 - val_accuracy: 0.6065
# Epoch 71/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.9190 - accuracy: 0.7240
# Epoch 71: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9191 - accuracy: 0.7240 - val_loss: 1.5326 - val_accuracy: 0.6027
# Epoch 72/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.9049 - accuracy: 0.7268
# Epoch 72: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.9046 - accuracy: 0.7269 - val_loss: 1.4393 - val_accuracy: 0.6130
# Epoch 73/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.8845 - accuracy: 0.7338
# Epoch 73: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.8848 - accuracy: 0.7337 - val_loss: 1.4972 - val_accuracy: 0.6093
# Epoch 74/130
# 625/625 [==============================] - ETA: 0s - loss: 0.8747 - accuracy: 0.7358
# Epoch 74: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8747 - accuracy: 0.7358 - val_loss: 1.4983 - val_accuracy: 0.6070
# Epoch 75/130
# 625/625 [==============================] - ETA: 0s - loss: 0.8798 - accuracy: 0.7348
# Epoch 75: val_loss did not improve from 1.41344
# 625/625 [==============================] - 36s 57ms/step - loss: 0.8798 - accuracy: 0.7348 - val_loss: 1.4996 - val_accuracy: 0.6093
# Epoch 76/130
# 625/625 [==============================] - ETA: 0s - loss: 0.8566 - accuracy: 0.7385
# Epoch 76: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.8566 - accuracy: 0.7385 - val_loss: 1.4464 - val_accuracy: 0.6132
# Epoch 77/130
# 625/625 [==============================] - ETA: 0s - loss: 0.8517 - accuracy: 0.7423
# Epoch 77: val_loss did not improve from 1.41344
# 625/625 [==============================] - 36s 57ms/step - loss: 0.8517 - accuracy: 0.7423 - val_loss: 1.4511 - val_accuracy: 0.6183
# Epoch 78/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.8372 - accuracy: 0.7475
# Epoch 78: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8375 - accuracy: 0.7474 - val_loss: 1.4551 - val_accuracy: 0.6167
# Epoch 79/130
# 625/625 [==============================] - ETA: 0s - loss: 0.8403 - accuracy: 0.7451
# Epoch 79: val_loss did not improve from 1.41344
# 625/625 [==============================] - 35s 55ms/step - loss: 0.8403 - accuracy: 0.7451 - val_loss: 1.4901 - val_accuracy: 0.6157
# Epoch 80/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.8219 - accuracy: 0.7479
# Epoch 80: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8221 - accuracy: 0.7478 - val_loss: 1.4363 - val_accuracy: 0.6213
# Epoch 81/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.8164 - accuracy: 0.7514
# Epoch 81: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.8161 - accuracy: 0.7515 - val_loss: 1.4355 - val_accuracy: 0.6175
# Epoch 82/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.7988 - accuracy: 0.7580
# Epoch 82: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.7990 - accuracy: 0.7580 - val_loss: 1.4439 - val_accuracy: 0.6256
# Epoch 83/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.7902 - accuracy: 0.7599
# Epoch 83: val_loss did not improve from 1.41344
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7901 - accuracy: 0.7599 - val_loss: 1.4764 - val_accuracy: 0.6160
# Epoch 84/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7867 - accuracy: 0.7585
# Epoch 84: val_loss did not improve from 1.41344
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7867 - accuracy: 0.7585 - val_loss: 1.4733 - val_accuracy: 0.6226
# Epoch 85/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.7752 - accuracy: 0.7598
# Epoch 85: val_loss did not improve from 1.41344
# 625/625 [==============================] - 33s 53ms/step - loss: 0.7749 - accuracy: 0.7598 - val_loss: 1.4346 - val_accuracy: 0.6251
# Epoch 86/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7649 - accuracy: 0.7632
# Epoch 86: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.7649 - accuracy: 0.7632 - val_loss: 1.4280 - val_accuracy: 0.6287
# Epoch 87/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.7648
# Epoch 87: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.7593 - accuracy: 0.7648 - val_loss: 1.4782 - val_accuracy: 0.6186
# Epoch 88/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7506 - accuracy: 0.7696
# Epoch 88: val_loss did not improve from 1.41344
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7506 - accuracy: 0.7696 - val_loss: 1.4733 - val_accuracy: 0.6243
# Epoch 89/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.7398 - accuracy: 0.7732
# Epoch 89: val_loss did not improve from 1.41344
# 625/625 [==============================] - 33s 53ms/step - loss: 0.7395 - accuracy: 0.7734 - val_loss: 1.4823 - val_accuracy: 0.6221
# Epoch 90/130
# 624/625 [============================>.] - ETA: 0s - loss: 0.7286 - accuracy: 0.7743
# Epoch 90: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.7289 - accuracy: 0.7742 - val_loss: 1.4485 - val_accuracy: 0.6285
# Epoch 91/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7249 - accuracy: 0.7754
# Epoch 91: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 54ms/step - loss: 0.7249 - accuracy: 0.7754 - val_loss: 1.4714 - val_accuracy: 0.6267
# Epoch 92/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.7806
# Epoch 92: val_loss did not improve from 1.41344
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7187 - accuracy: 0.7806 - val_loss: 1.4591 - val_accuracy: 0.6269
# Epoch 93/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7116 - accuracy: 0.7797
# Epoch 93: val_loss did not improve from 1.41344
# 625/625 [==============================] - 33s 53ms/step - loss: 0.7116 - accuracy: 0.7797 - val_loss: 1.4340 - val_accuracy: 0.6329
# Epoch 94/130
# 625/625 [==============================] - ETA: 0s - loss: 0.7077 - accuracy: 0.7810
# Epoch 94: val_loss did not improve from 1.41344
# 625/625 [==============================] - 34s 55ms/step - loss: 0.7077 - accuracy: 0.7810 - val_loss: 1.4737 - val_accuracy: 0.6303
# Epoch 94: early stopping
# Training time: 5245.79937005043

# %%
HISTORY.append(history_op)

# %%
# Visualize training process
training_plot(history_op)

# %% [markdown]
# Se aprecia en ambas gráficas los resultados con el conjunto de datos de validación están bastante parejos a los de entrenamiento hasta apróximadamente la epoch número 40. Además se observa como el sobreentrenamiento producido en los modelos anteriores ha desaparecido por lo cual nos indica que el uso de dropout está mejorando el rendimiento significativamente.

# %% [markdown]
# ####Rendimiento

# %%
scores_op = model_op.evaluate(test_data, test_labels)
TEST_LOSS.append(scores_op[0])
TEST_ACC.append(scores_op[1])
print(f'accuracy on test set: {model_op.metrics_names[1]} of {scores_op[1]*100}')
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4384 - accuracy: 0.6416
# accuracy on test set: accuracy of 64.16000127792358

# %% [markdown]
# Con los datos anteriormente descritos se obtienen los siguientes valores:
# *   Tiempo de ejecución: ~5245 s.en 96 epochs.
# *   Precisión con los datos de test: ~65%

# %% [markdown]
# #Evolución

# %% [markdown]
# A continuación las gráficas correspondientes a la pérdida y precisión con los datos de entrenamiento de los 3 modelos.

# %%
title = ['ModeloBase', 'ModeloBase + DataAugmentation', 'ModeloOptimizado + DataAugmentation']
curvas_aprendizaje(HISTORY[:2], 3, 2, (16,16), title)

# %%
curvas_aprendizaje(HISTORY[2:], 3, 2, (22,14),
                   title[2:])

# %% [markdown]
# Se observa como para el modelo base la pérdida y precisión convergen muy rápidamente alcanzando una cota alta con muy pocas épocas. Para el modelo base con data augmentation ambas medidas convergen más lentamente con un número similar de épocas y para el modelo optimizado con data augmentation la convergencia es mucho más suave en un número de épocas mucho mayor. Suavizar la convergencia del modelo se consigue mediante el uso de optimizadores y data augmentation y consigue que el modelo sea capaz de reconocer de manera más óptima las imágenes de validación.

# %% [markdown]
# A continuación se añade una gráfica con los tiempos de ejecución de cada modelo.

# %% [markdown]
# | Modelo          	| Coste Temporal (segundos) 	|
# |-----------------	|---------------------------	|
# | Base            	| 644                       	|
# | Base + DA       	| 1708                      	|
# | Optimizado + DA 	| 5245                      	|

# %% [markdown]
# El indicador de tiempo nos pueda dar una medida de la complejidad de los distintos modelos ya que los 3 han sido ejecutados en las mismas condiciones de capacidad de proceso y recursos. En la tabla anterior se observa que el algoritmo base es el que se ejecuta más rápidamente. El resultado es lógico ya que es el algoritmo más sencillo aunque la salida del mismo es la menos precisa. En el caso 2 el tiempo se incrementa al igual que la precisión. En el caso 3 el tiempo se incrementa de una manera significativa debido a la mayor complejidad del modelo y al aumento de epochs para alcanzar un incremento significativo de la precisión.

# %% [markdown]
# Por último se gráfica por medio de un grafico de barras los datos de pérdida y precisión obtenidos sobre los datos de test.

# %%
testerror_testacc(TEST_LOSS, TEST_ACC, title, (15, 5))

# %% [markdown]
# Si se comparan el modelo base con el mismo modelo con data agumentation se aprecia como el uso de la técnica de data augmentaton sobre el modelo base produce en la pérdida una mejoría del 27% aprox. y del 7% aprox. en la precisión.
# Al comparar el modelo base con data augmentation con el modelo optimizado con data agumentation se observa que el uso de los optimizadores mejoran significativamente el rendimiento del modelo produciendo una mejoría del 66% respecto a la pérdida y del 20% respecto a la precisión.
#
# Remarcar que la mejoría en los datos de test entre el modelo base con data augmentation y el optimizado es posible debido a la eliminación del sobreentrenamiento el cual impedía que el modelo base con data augmentation se entrenara adecuadamante afectando en su rendimiento.

# %% [markdown]
# #Conclusiones

# %% [markdown]
# El reconocimiento de imágenes es una tarea sencilla para los humanos, ya que nos resulta fácil distinguir entre diferentes características. De alguna manera, nuestros cerebros se entrenan inconscientemente con un tipo similar de imágenes que han ayudado a que distingamos entre las características de las imágenes sin poner mucho esfuerzo en la tarea. Por ejemplo, después de ver algunos gatos, podemos reconocer casi todos los tipos diferentes de gatos que encontramos en nuestra vida. Sin embargo, las máquinas necesitan de mucho entrenamiento para la extracción de características lo cual lo convierte en un desafío debido al alto coste de cálculo, requerimiento de memoria y unidades de procesamiento.
#
# Con el modelo optimizado es capaz de obtener una precisión del 65% aproximádamente en un tiempo de (5245 en 96 epochs). Sin embargo, el modelo base con data augmentation es capaz de obtener una precisión del 47% apróximadamente en una cantidad de tiempo inferior (1708 en 30 epochs). Ello indica que el equilibrio entre rendimiento y precisión es una de las claves para optimizar las necesidades de precisión en un entorno determinado con las capacidades necesarias para tal fin. La variación de parámetros de `imagedatagenerator()` para mejorar el rendimiento es fundamental así como el uso de optimizadores para evitar la aparición de sobreentrenamiento en los modelos y ser capaces de encontrar soliciones óptimas entre las precisiones requeridas y las capacidades necesarias para alcanzarlas reduciendo los cálculos residuales e ineficientes de los procesos de entrenamiento.
